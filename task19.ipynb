# %% [markdown]
# <a href="https://colab.research.google.com/github/dhoneshruti59-cloud/pandas/blob/main/task19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9de29083-bda8-4d28-9600-9a092873aaf7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9de29083-bda8-4d28-9600-9a092873aaf7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath="/content/car_price_prediction_with_missing.csv"
df=pd.read_csv("car_price_prediction_with_missing.csv")

# %%
df
# Out:
#       Car ID   Brand    Year  Engine Size Fuel Type Transmission   Mileage  \
# 0        1.0   Tesla  2016.0          2.3    Petrol       Manual  114832.0
# 1        2.0     BMW  2018.0          4.4  Electric       Manual  143190.0
# 2        3.0    Audi  2013.0          4.5  Electric       Manual  181601.0
# 3        4.0   Tesla  2011.0          4.1    Diesel    Automatic   68682.0
# 4        5.0    Ford  2009.0          2.6    Diesel       Manual  223009.0
# ...      ...     ...     ...          ...       ...          ...       ...
# 2495  2496.0    Audi  2020.0          2.4    Petrol    Automatic   22650.0
# 2496  2497.0    Audi  2001.0          5.7    Hybrid       Manual   77701.0
# 2497     NaN     NaN     NaN          NaN       NaN          NaN       NaN
# 2498  2499.0    Audi  2002.0          4.5    Diesel       Manual  229164.0
# 2499  2500.0  Toyota  2005.0          4.6    Diesel    Automatic   80978.0
#
#      Condition     Price     Model
# ...

# %%
df.head(10)
# Out:
#    Car ID  Brand    Year  Engine Size Fuel Type Transmission   Mileage  \
# 0     1.0  Tesla  2016.0          2.3    Petrol       Manual  114832.0
# 1     2.0    BMW  2018.0          4.4  Electric       Manual  143190.0
# 2     3.0   Audi  2013.0          4.5  Electric       Manual  181601.0
# 3     4.0  Tesla  2011.0          4.1    Diesel    Automatic   68682.0
# 4     5.0   Ford  2009.0          2.6    Diesel       Manual  223009.0
# 5     6.0   Audi  2019.0          2.4    Diesel    Automatic  246553.0
# 6     7.0   Audi  2020.0          4.0  Electric    Automatic  135486.0
# 7     8.0  Tesla  2017.0          5.3    Hybrid    Automatic   83030.0
# 8     9.0  Honda  2023.0          5.7  Electric       Manual  120360.0
# 9    10.0   Ford  2010.0          1.5  Electric    Automatic  135009.0
#
#   Condition     Price     Model
# 0       New  26613.92   Model X
# 1      Used  14679.61  5 Series
# 2       New  44402.61        A4
# 3       New  86374.33   Model Y
# ...

# %%
missing_value=df.isnull().sum()
print("missing value:",missing_value)
percentage=(missing_value/len(df))*100
print("percentage:",percentage)
# Out:
# missing value: Car ID          250
# Brand           250
# Year            250
# Engine Size     250
# Fuel Type       250
# Transmission    250
# Mileage         250
# Condition       250
# Price           250
# Model           250
# dtype: int64
# percentage: Car ID          10.0
# Brand           10.0
# Year            10.0
# Engine Size     10.0
# Fuel Type       10.0
# Transmission    10.0
# Mileage         10.0
# Condition       10.0
# Price           10.0
# Model           10.0
# dtype: float64

# %%
df.dropna()
# Out:
#       Car ID     Brand    Year  Engine Size Fuel Type Transmission   Mileage  \
# 0        1.0     Tesla  2016.0          2.3    Petrol       Manual  114832.0
# 1        2.0       BMW  2018.0          4.4  Electric       Manual  143190.0
# 2        3.0      Audi  2013.0          4.5  Electric       Manual  181601.0
# 3        4.0     Tesla  2011.0          4.1    Diesel    Automatic   68682.0
# 4        5.0      Ford  2009.0          2.6    Diesel       Manual  223009.0
# ...      ...       ...     ...          ...       ...          ...       ...
# 2494  2495.0  Mercedes  2001.0          2.3    Petrol       Manual  162586.0
# 2495  2496.0      Audi  2020.0          2.4    Petrol    Automatic   22650.0
# 2496  2497.0      Audi  2001.0          5.7    Hybrid       Manual   77701.0
# 2498  2499.0      Audi  2002.0          4.5    Diesel       Manual  229164.0
# 2499  2500.0    Toyota  2005.0          4.6    Diesel    Automatic   80978.0
#
#      Condition     Price     Model
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(249)

# %%
df.drop_duplicates()
# Out:
#       Car ID     Brand    Year  Engine Size Fuel Type Transmission   Mileage  \
# 0        1.0     Tesla  2016.0          2.3    Petrol       Manual  114832.0
# 1        2.0       BMW  2018.0          4.4  Electric       Manual  143190.0
# 2        3.0      Audi  2013.0          4.5  Electric       Manual  181601.0
# 3        4.0     Tesla  2011.0          4.1    Diesel    Automatic   68682.0
# 4        5.0      Ford  2009.0          2.6    Diesel       Manual  223009.0
# ...      ...       ...     ...          ...       ...          ...       ...
# 2494  2495.0  Mercedes  2001.0          2.3    Petrol       Manual  162586.0
# 2495  2496.0      Audi  2020.0          2.4    Petrol    Automatic   22650.0
# 2496  2497.0      Audi  2001.0          5.7    Hybrid       Manual   77701.0
# 2498  2499.0      Audi  2002.0          4.5    Diesel       Manual  229164.0
# 2499  2500.0    Toyota  2005.0          4.6    Diesel    Automatic   80978.0
#
#      Condition     Price     Model
# ...

# %%
df.shape
# Out:
# (2500, 10)

# %%
df.describe()
# Out:
#             Car ID         Year  Engine Size        Mileage         Price
# count  2250.000000  2250.000000  2250.000000    2250.000000   2250.000000
# mean   1251.243556  2011.577778     3.485467  150236.178222  52506.874391
# std     725.637358     6.980468     1.427690   88150.746556  27232.417079
# min       1.000000  2000.000000     1.000000      15.000000   5011.270000
# 25%     627.250000  2005.000000     2.300000   71178.500000  28985.052500
# 50%    1249.500000  2012.000000     3.450000  149762.000000  53485.240000
# 75%    1875.250000  2018.000000     4.700000  226299.000000  75560.340000
# max    2500.000000  2023.000000     6.000000  299967.000000  99982.590000

# %%
print("mean:",df['Year'].mean())
print("minimum:",df['Year'].min())
print("maximum:",df['Year'].max())
print("median:",df['Year'].median())
# Out:
# mean: 2011.5777777777778
# minimum: 2000.0
# maximum: 2023.0
# median: 2012.0

# %%
plt.subplot(2,2,1)
sns.histplot(df['Price'])

plt.subplot(2,2,2)
sns.histplot(df['Mileage'])

plt.subplot(2,2,3)
sns.histplot(df['Year'])

plt.subplot(2,2,4)
sns.histplot(df['Engine Size'])
plt.tight_layout()

# %%
c=df.select_dtypes(include='object').columns
print("Categorical columns:",c)
# Out:
# Categorical columns: Index(['Brand', 'Fuel Type', 'Transmission', 'Condition', 'Model'], dtype='object')

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df,x='Fuel Type')

plt.figure(figsize=(8,4))
sns.countplot(data=df,x='Brand')

plt.figure(figsize=(8,4))
sns.countplot(data=df,x='Transmission')

plt.figure(figsize=(8,4))
sns.countplot(data=df,x='Condition')

plt.figure(figsize=(8,4))
sns.countplot(data=df,x='Model')
plt.show()

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
print("Numerical columns:",numeric_df)
corr_matrix = numeric_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Numerical columns:       Car ID    Year  Engine Size   Mileage     Price
# 0        1.0  2016.0          2.3  114832.0  26613.92
# 1        2.0  2018.0          4.4  143190.0  14679.61
# 2        3.0  2013.0          4.5  181601.0  44402.61
# 3        4.0  2011.0          4.1   68682.0  86374.33
# 4        5.0  2009.0          2.6  223009.0  73577.10
# ...      ...     ...          ...       ...       ...
# 2495  2496.0  2020.0          2.4   22650.0  61384.10
# 2496  2497.0  2001.0          5.7   77701.0  24710.35
# 2497     NaN     NaN          NaN       NaN       NaN
# 2498  2499.0  2002.0          4.5  229164.0  46085.67
# 2499  2500.0  2005.0          4.6   80978.0  16594.14
#
# [2500 rows x 5 columns]

# %%
X = df.drop('Price', axis=1)
y = df['Price']
print("Independent Features (X):")
print(X.columns)
print("\nDependent Feature (y):")
print(y.name)
# Out:
# Independent Features (X):
# Index(['Car ID', 'Brand', 'Year', 'Engine Size', 'Fuel Type', 'Transmission',
#        'Mileage', 'Condition', 'Model'],
#       dtype='object')
#
# Dependent Feature (y):
# Price

# %%
print("Before Encoding:")
print(df[['Brand', 'Fuel Type']].head())
df_encoded = pd.get_dummies(df, columns=['Brand', 'Model', 'Fuel Type', 'Transmission', 'Condition'], drop_first=True)
print("\nAfter Encoding:")
print(df_encoded.head())
print("\nShape after encoding:", df_encoded.shape)
# Out:
# Before Encoding:
#    Brand Fuel Type
# 0  Tesla    Petrol
# 1    BMW  Electric
# 2   Audi  Electric
# 3  Tesla    Diesel
# 4   Ford    Diesel
#
# After Encoding:
#    Car ID    Year  Engine Size   Mileage     Price  Brand_BMW  Brand_Ford  \
# 0     1.0  2016.0          2.3  114832.0  26613.92      False       False
# 1     2.0  2018.0          4.4  143190.0  14679.61       True       False
# 2     3.0  2013.0          4.5  181601.0  44402.61      False       False
# 3     4.0  2011.0          4.1   68682.0  86374.33      False       False
# 4     5.0  2009.0          2.6  223009.0  73577.10      False        True
#
#    Brand_Honda  Brand_Mercedes  Brand_Tesla  ...  Model_Q7  Model_RAV4  \
# 0        False           False         True  ...     False       False
# 1        False           False        False  ...     False       False
# 2        False           False        False  ...     False       False
# 3        False           False         True  ...     False       False
# ...

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
X = df_encoded.drop('Price', axis=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
print(X_scaled.head(5))
# Out:
#      Car ID      Year  Engine Size   Mileage  Brand_BMW  Brand_Ford  \
# 0 -1.723342  0.633654    -0.830523 -0.401721  -0.387239   -0.374154
# 1 -1.721964  0.920232     0.640711 -0.079951   2.582385   -0.374154
# 2 -1.720585  0.203788     0.710770  0.355888  -0.387239   -0.374154
# 3 -1.719207 -0.082789     0.430535 -0.925373  -0.387239   -0.374154
# 4 -1.717829 -0.369366    -0.620347  0.825733  -0.387239    2.672699
#
#    Brand_Honda  Brand_Mercedes  Brand_Tesla  Brand_Toyota  ...  Model_Q7  \
# 0     -0.37137       -0.390647     2.638519     -0.400788  ... -0.182989
# 1     -0.37137       -0.390647    -0.379000     -0.400788  ... -0.182989
# 2     -0.37137       -0.390647    -0.379000     -0.400788  ... -0.182989
# 3     -0.37137       -0.390647     2.638519     -0.400788  ... -0.182989
# 4     -0.37137       -0.390647    -0.379000     -0.400788  ... -0.182989
#
#    Model_RAV4  Model_X3  Model_X5  Fuel Type_Electric  Fuel Type_Hybrid  \
# ...
